# %%
import pandas as pd
import numpy as np
import pandas_profiling
from scipy.cluster.hierarchy import dendrogram, linkage

import seaborn as sns
from matplotlib import pyplot as plt

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %%
df_train = pd.read_csv('./Datasets/clean_train_data.csv')
df_test = pd.read_csv('./Datasets/clean_test_data.csv')
df_labels = pd.read_csv('./Datasets/Training_labels.csv')
df_train2 = pd.read_csv('./Datasets/Training_values.csv')

# %%
df_train.head()
# Out:
#       id  amount_tsh date_recorded  gps_height  longitude   latitude  \
# 0  69572      6000.0    2011-03-14        1390  34.938093  -9.856322
# 1   8776         0.0    2013-03-06        1399  34.698766  -2.147466
# 2  34310        25.0    2013-02-25         686  37.460664  -3.821329
# 3  67743         0.0    2013-01-28         263  38.486161 -11.155298
# 4  19728         0.0    2011-07-13           0  31.130847  -1.825359
#
#                wpt_name  num_private                    basin   region  \
# 0                  none            0               Lake Nyasa   Iringa
# 1              Zahanati            0            Lake Victoria     Mara
# 2           Kwa Mahundi            0                  Pangani  Manyara
# 3  Zahanati Ya Nanyumbu            0  Ruvuma / Southern Coast   Mtwara
# 4               Shuleni            0            Lake Victoria   Kagera
#
#         ...        extraction_type_class  management management_group  \
# 0       ...                      gravity         vwc       user-group
# 1       ...                      gravity         wug       user-group
# 2       ...                      gravity         vwc       user-group
# 3       ...                  submersible         vwc       user-group
# 4       ...                      gravity       other            other
#
#           payment  quality_group      quantity                source  \
# 0    pay annually           good        enough                spring
# 1       never pay           good  insufficient  rainwater harvesting
# 2  pay per bucket           good        enough                   dam
# 3       never pay           good           dry           machine dbh
# 4       never pay           good      seasonal  rainwater harvesting
#
#   source_class              waterpoint_type    status_group
# 0  groundwater           communal standpipe      functional
# 1      surface           communal standpipe      functional
# 2      surface  communal standpipe multiple      functional
# 3  groundwater  communal standpipe multiple  non functional
# 4      surface           communal standpipe      functional
#
# [5 rows x 27 columns]

# %%
df_train = pd.merge(df_train2, df_labels)

# %%
sns.set(style="ticks", color_codes=True)
# iris = sns.load_dataset("iris")
g = sns.pairplot(df_train)

# %%
df_train.basin.value_counts()
# Out:
# Lake Victoria              10248
# Pangani                     8940
# Rufiji                      7976
# Internal                    7785
# Lake Tanganyika             6432
# Wami / Ruvu                 5987
# Lake Nyasa                  5085
# Ruvuma / Southern Coast     4493
# Lake Rukwa                  2454
# Name: basin, dtype: int64

# %%
# Create a new column to explore what variables in columns have more 
# functional or more broken and non functional pumps.

replace_values = {'functional':2, 'functional needs repair':1,
                   'non functional':0}

df_train['status_values']  = df_train.status_group.replace(replace_values)

# %%
df_train['status_values'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    0
# 4    2
# Name: status_values, dtype: int64

# %%
# See what basin area has the most functional and lest functional pumps
piv = pd.pivot_table(df_train, index=['basin', 'status_group'],
                           values=['status_values'], aggfunc='count')
piv
# Out:
#                                                  status_values
# basin                   status_group
# Internal                functional                        4482
#                         functional needs repair            557
#                         non functional                    2746
# Lake Nyasa              functional                        3324
#                         functional needs repair            250
#                         non functional                    1511
# Lake Rukwa              functional                        1000
#                         functional needs repair            270
#                         non functional                    1184
# Lake Tanganyika         functional                        3107
#                         functional needs repair            742
#                         non functional                    2583
# Lake Victoria           functional                        5100
#                         functional needs repair            989
#                         non functional                    4159
# Pangani                 functional                        5372
#                         functional needs repair            477
#                         non functional                    3091
# Rufiji                  functional                        5068
#                         functional needs repair            437
#                         non functional                    2471
# Ruvuma / Southern Coast functional                        1670
#                         functional needs repair            326
#                         non functional                    2497
# Wami / Ruvu             functional                        3136
#                         functional needs repair            269
#                         non functional                    2582

# %%
piv.plot(kind="bar").legend()

# %%
df_train.groupby('basin')['status_group']\
    .value_counts()\
    .unstack(level=1)\
    .plot.barh(figsize=(10,7))\

# %%
list(df_train.columns)
# Out:
# ['id',
#  'amount_tsh',
#  'date_recorded',
#  'funder',
#  'gps_height',
#  'installer',
#  'longitude',
#  'latitude',
#  'wpt_name',
#  'num_private',
#  'basin',
#  'subvillage',
#  'region',
#  'region_code',
#  'district_code',
#  'lga',
#  'ward',
#  'population',
#  'public_meeting',
#  'recorded_by',
#  'scheme_management',
#  'scheme_name',
#  'permit',
#  'construction_year',
#  'extraction_type',
#  'extraction_type_group',
#  'extraction_type_class',
#  'management',
#  'management_group',
#  'payment',
#  'payment_type',
#  'water_quality',
#  'quality_group',
#  'quantity',
#  'quantity_group',
#  'source',
#  'source_type',
#  'source_class',
#  'waterpoint_type',
#  'waterpoint_type_group',
#  'status_group',
#  'status_values']

# %%
df_train.groupby('payment')['status_group']\
    .value_counts()\
    .unstack(level=1)\
    .plot.barh(figsize=(10,7))\

# %%
df_train.groupby('construction_year')['status_group']\
    .value_counts()\
    .unstack(level=1)\
    .plot.barh(figsize=(10,7))\

# %%
df_train.groupby('quality_group')['status_group']\
    .value_counts()\
    .unstack(level=1)\
    .plot.barh(figsize=(10,7))\

# %%
df_train.groupby('waterpoint_type')['status_group']\
    .value_counts()\
    .unstack(level=1)\
    .plot.barh(figsize=(10,7))\

# %%
df_train.groupby('source')['status_group']\
    .value_counts()\
    .unstack(level=1)\
    .plot.barh(figsize=(10,7))\

# %%
df_train.groupby('extraction_type_class')['status_group']\
    .value_counts()\
    .unstack(level=1)\
    .plot.barh(figsize=(10,7))\

# %%
df_train2.date_recorded = pd.datetime(2013, 12, 3) - pd.to_datetime(df_train2.date_recorded)
df_train2.columns = ['days_since_recorded' if x=='date_recorded' else x for x in df_train2.columns]
df_train2.days_since_recorded = df_train2.days_since_recorded.astype('timedelta64[D]').astype(int)
df_train2.days_since_recorded.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-294-82aa77dfd599> in <module>()
# ----> 1 df_train2.date_recorded = pd.datetime(2013, 12, 3) - pd.to_datetime(df_train2.date_recorded)
#       2 df_train2.columns = ['days_since_recorded' if x=='date_recorded' else x for x in df_train2.columns]
#       3 df_train2.days_since_recorded = df_train2.days_since_recorded.astype('timedelta64[D]').astype(int)
#       4 df_train2.days_since_recorded.describe()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'date_recorded'

# %%
df_train2.days_since_recorded
# Out:
# 0         995
# 1         272
# 2         281
# 3         309
# 4         874
# 5         996
# 6         428
# 7         420
# 8         395
# 9         853
# 10       1017
# 11        288
# 12        415
# 13        263
# 14        409
# 15        852
# 16        883
# 17        821
# 18        865
# 19       1015
# 20       1010
# 21        296
# 22        791
# 23         30
# 24        316
# 25        281
# 26        321
# 27        876
# 28        273
# 29        262
#          ...
# 59370     308
# 59371     420
# 59372     398
# 59373     307
# 59374     400
# 59375     853
# 59376     303
# 59377     406
# 59378     988
# 59379     874
# 59380     995
# 59381     993
# 59382     122
# 59383     318
# 59384     877
# 59385     395
# 59386     834
# 59387     266
# 59388     308
# 59389     850
# 59390     852
# 59391     122
# 59392     963
# 59393     402
# 59394    1000
# 59395     214
# 59396     941
# 59397     967
# 59398    1001
# 59399     986
# Name: days_since_recorded, Length: 59400, dtype: int64

# %%
df_labels.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
df_test.head()
# Out:
#       id  amount_tsh date_recorded  gps_height  longitude   latitude  \
# 0  50785         0.0    2013-02-04        1996  35.290799  -4.059696
# 1  51630         0.0    2013-02-04        1569  36.656709  -3.309214
# 2  17168         0.0    2013-02-01        1567  34.767863  -5.004344
# 3  45559         0.0    2013-01-22         267  38.058046  -9.418672
# 4  49871       500.0    2013-03-27        1260  35.006123 -10.950412
#
#                   wpt_name  num_private                    basin   region  \
# 0  Dinamu Secondary School            0                 Internal  Manyara
# 1                  Kimnyak            0                  Pangani   Arusha
# 2           Puma Secondary            0                 Internal  Singida
# 3           Kwa Mzee Pange            0  Ruvuma / Southern Coast    Lindi
# 4          Kwa Mzee Turuka            0  Ruvuma / Southern Coast   Ruvuma
#
#           ...          extraction_type_group  extraction_type_class  \
# 0         ...                          other                  other
# 1         ...                        gravity                gravity
# 2         ...                          other                  other
# 3         ...                          other                  other
# 4         ...                        gravity                gravity
#
#     management management_group      payment quality_group      quantity  \
# 0   parastatal       parastatal    never pay          good      seasonal
# 1          vwc       user-group    never pay          good  insufficient
# 2          vwc       user-group    never pay          good  insufficient
# 3          vwc       user-group      unknown          good           dry
# 4  water board       user-group  pay monthly          good        enough
#
#                  source source_class     waterpoint_type
# 0  rainwater harvesting      surface               other
# 1                spring  groundwater  communal standpipe
# 2  rainwater harvesting      surface               other
# 3          shallow well  groundwater               other
# 4                spring  groundwater  communal standpipe
#
# [5 rows x 26 columns]

# %%
predict = pd.read_csv('./Submissions/Submission_8.csv')

# %%
df_merge2 = pd.merge(predict, df_test, on='id')

# %%
df_merge2.head(20)
# Out:
#        id    status_group  amount_tsh date_recorded  gps_height  longitude  \
# 0   50785      functional         0.0    2013-02-04        1996  35.290799
# 1   51630      functional         0.0    2013-02-04        1569  36.656709
# 2   17168      functional         0.0    2013-02-01        1567  34.767863
# 3   45559      functional         0.0    2013-01-22         267  38.058046
# 4   49871      functional       500.0    2013-03-27        1260  35.006123
# 5   52449      functional         0.0    2013-03-04        1685  36.685279
# 6   24806      functional         0.0    2011-03-02         550  36.398041
# 7   28965      functional         0.0    2013-01-25         234  39.607420
# 8   36301  non functional        30.0    2013-01-23         584  39.262951
# 9   54122  non functional         0.0    2013-03-18        1083  37.096108
# 10    419      functional         5.0    2013-10-03        1259  37.233248
# 11  45750      functional         0.0    2013-02-27         608  37.686392
# 12    653      functional         0.0    2012-10-11           0  33.661074
# 13  14017      functional         0.0    2011-07-29           0  33.007680
# 14  44607      functional      1000.0    2011-03-02        1625  35.615624
# 15  40228      functional      1200.0    2013-06-03         916  35.482886
# 16  27714      functional         0.0    2011-02-24         -39  39.850190
# 17  28785      functional       200.0    2011-03-11        1793  38.254024
# 18  28330      functional         0.0    2012-10-06           0  31.586798
# 19  18532      functional         0.0    2013-02-02         368  39.438526
#
#      latitude                 wpt_name  num_private                    basin  \
# 0   -4.059696  Dinamu Secondary School            0                 Internal
# 1   -3.309214                  Kimnyak            0                  Pangani
# 2   -5.004344           Puma Secondary            0                 Internal
# 3   -9.418672           Kwa Mzee Pange            0  Ruvuma / Southern Coast
# 4  -10.950412          Kwa Mzee Turuka            0  Ruvuma / Southern Coast
# 5   -3.302420                   Masaga            0                  Pangani
# 6   -7.541382                     none            0                   Rufiji
# 7  -10.893786                Kwa Mkwaa            0  Ruvuma / Southern Coast
# 8  -10.823588           Kwa Mzee Mpini            0  Ruvuma / Southern Coast
# 9   -3.251754           Kwa Flora Daud            0                  Pangani
# 10  -3.241121          Kwa Anna P Muro            0                  Pangani
# 11  -4.555975                  Shuleni            0                  Pangani
# 12  -4.165720                Kwa Nzega            0                 Internal
# 13  -3.209529          Gati La Shuleni            0            Lake Victoria
# 14  -7.870290                     none            0                   Rufiji
# 15 -10.912596              Kwa Daniela            0  Ruvuma / Southern Coast
# 16  -7.727946                 Kitotoni            0                   Rufiji
# 17  -4.565802         Magagai Hospital            0                  Pangani
# 18  -3.387808    Shule Ya Msingi Ikuzi            0          Lake Tanganyika
# 19 -10.583366                Liponde A            0  Ruvuma / Southern Coast
#
#                ...              extraction_type_group  extraction_type_class  \
# 0              ...                              other                  other
# 1              ...                            gravity                gravity
# 2              ...                              other                  other
# 3              ...                              other                  other
# 4              ...                            gravity                gravity
# 5              ...                            gravity                gravity
# 6              ...                      india mark ii               handpump
# 7              ...                        submersible            submersible
# 8              ...                            gravity                gravity
# 9              ...                            gravity                gravity
# 10             ...                            gravity                gravity
# 11             ...                              other                  other
# 12             ...                               mono              motorpump
# 13             ...                               mono              motorpump
# 14             ...                            gravity                gravity
# 15             ...                            gravity                gravity
# 16             ...                        nira/tanira               handpump
# 17             ...                            gravity                gravity
# 18             ...                            gravity                gravity
# 19             ...                        submersible            submersible
#
#      management management_group         payment  quality_group      quantity  \
# 0    parastatal       parastatal       never pay           good      seasonal
# 1           vwc       user-group       never pay           good  insufficient
# 2           vwc       user-group       never pay           good  insufficient
# 3           vwc       user-group         unknown           good           dry
# 4   water board       user-group     pay monthly           good        enough
# 5           vwc       user-group       never pay           good        enough
# 6           vwc       user-group       never pay          salty        enough
# 7           vwc       user-group       never pay           good           dry
# 8           vwc       user-group  pay per bucket           good  insufficient
# 9   water board       user-group     pay monthly           good        enough
# 10  water board       user-group  pay per bucket           good        enough
# 11          vwc       user-group       never pay           good           dry
# 12          vwc       user-group         unknown           good           dry
# 13          vwc       user-group  pay per bucket           good        enough
# 14          vwc       user-group     pay monthly           good        enough
# 15          vwc       user-group    pay annually           good        enough
# 16          vwc       user-group       never pay           good        enough
# 17          vwc       user-group     pay monthly           good        enough
# 18   parastatal       parastatal         unknown           good      seasonal
# 19          vwc       user-group       never pay           good           dry
#
#                   source source_class              waterpoint_type
# 0   rainwater harvesting      surface                        other
# 1                 spring  groundwater           communal standpipe
# 2   rainwater harvesting      surface                        other
# 3           shallow well  groundwater                        other
# 4                 spring  groundwater           communal standpipe
# 5                 spring  groundwater           communal standpipe
# 6            machine dbh  groundwater                    hand pump
# 7            machine dbh  groundwater  communal standpipe multiple
# 8                 spring  groundwater           communal standpipe
# 9                 spring  groundwater           communal standpipe
# 10                spring  groundwater           communal standpipe
# 11  rainwater harvesting      surface                        other
# 12           machine dbh  groundwater  communal standpipe multiple
# 13           machine dbh  groundwater  communal standpipe multiple
# 14                spring  groundwater           communal standpipe
# 15                 river      surface  communal standpipe multiple
# 16          shallow well  groundwater                    hand pump
# 17                spring  groundwater           communal standpipe
# 18  rainwater harvesting      surface           communal standpipe
# 19           machine dbh  groundwater           communal standpipe
#
# [20 rows x 27 columns]

# %%
predict.head(20)
# Out:
#        id    status_group
# 0   50785      functional
# 1   51630      functional
# 2   17168      functional
# 3   45559      functional
# 4   49871      functional
# 5   52449      functional
# 6   24806      functional
# 7   28965      functional
# 8   36301  non functional
# 9   54122  non functional
# 10    419      functional
# 11  45750      functional
# 12    653      functional
# 13  14017      functional
# 14  44607      functional
# 15  40228      functional
# 16  27714      functional
# 17  28785      functional
# 18  28330      functional
# 19  18532      functional

# %%
predict_map = df_merge2[['id', 'status_group', 'longitude', 'latitude']]

# %%
predict_map.head()
# Out:
#       id status_group  longitude   latitude
# 0  50785   functional  35.290799  -4.059696
# 1  51630   functional  36.656709  -3.309214
# 2  17168   functional  34.767863  -5.004344
# 3  45559   functional  38.058046  -9.418672
# 4  49871   functional  35.006123 -10.950412

# %%
predict['status_group'].unique()
# Out:
# array(['functional', 'non functional', 'functional needs repair'],
#       dtype=object)

# %%
predict_map.to_csv('./Datasets/Map_predictions.csv')

# %%
df_test.sort_values(by='id')
# Out:
#           id  amount_tsh date_recorded  gps_height  longitude      latitude  \
# 3402      10         0.0    2011-03-13         197  38.790694 -5.113207e+00
# 14136     13         0.0    2013-02-08         803  36.905545 -1.076560e+01
# 5702      14         0.0    2013-03-27        1804  36.570357 -3.251609e+00
# 11739     29         0.0    2011-04-11           0  35.882325 -6.067613e+00
# 785       32         0.0    2011-07-27           0  33.886334 -9.457260e+00
# 6376      37         0.0    2011-11-03        2223  34.426782 -9.297329e+00
# 405       47         0.0    2011-08-20        1547  31.985216 -8.796667e+00
# 114       53        50.0    2013-04-04        1414  36.674327 -3.357425e+00
# 5869      57         0.0    2011-07-17           0  32.914140 -2.590667e+00
# 4105      58         0.0    2013-02-13        1514  34.681520 -5.062091e+00
# 53        59         0.0    2012-10-15           0  33.590722 -3.719552e+00
# 6433      61         0.0    2012-10-22           0  32.636323 -5.096151e+00
# 3463      72         0.0    2011-08-11         758  30.840207 -7.905154e+00
# 8679      83        25.0    2013-03-04         838  37.732475 -4.066418e+00
# 10067     85       500.0    2013-01-18        1283  30.481583 -5.614679e+00
# 3121      90         0.0    2013-01-18        1337  30.576451 -3.831490e+00
# 5965      99         0.0    2011-07-16           0   0.000000 -2.000000e-08
# 9604     100         0.0    2011-03-27        1712  34.985559 -8.672355e+00
# 14655    101         0.0    2013-03-20        1389  36.931788 -3.153520e+00
# 4635     110         0.0    2011-07-17           0  33.818112 -9.553647e+00
# 12301    127         0.0    2012-10-04           0  33.447212 -3.573401e+00
# 10174    131         0.0    2013-03-13        1665  37.913145 -4.176564e+00
# 7166     135         0.0    2011-08-07           0  32.055508 -2.397158e+00
# 3535     141         0.0    2013-01-16        1616  34.446502 -4.288655e+00
# 11581    143         0.0    2013-03-19        1239  35.774662 -2.144847e+00
# 10396    154         0.0    2011-07-29        1195  33.024368 -2.018537e+00
# 3640     155         0.0    2011-02-28         427  37.820673 -6.832344e+00
# 12658    156         0.0    2013-03-13        1508  36.751072 -3.352037e+00
# 12180    163      5000.0    2011-08-01         905  31.395316 -7.245880e+00
# 12478    172         0.0    2011-04-12           0  33.848236 -9.355346e+00
# ...      ...         ...           ...         ...        ...           ...
# 6055   74119         0.0    2011-07-06           0  33.621323 -9.207728e+00
# 9671   74132        30.0    2011-03-03         196  38.846407 -5.158815e+00
# 2274   74137       500.0    2011-03-10        1960  34.360196 -9.606514e+00
# 7075   74138         0.0    2013-02-09        1279  34.297786 -1.689185e+00
# 6979   74143         0.0    2011-03-15        1772  34.819473 -8.971041e+00
# 14021  74148        20.0    2013-01-26         834  37.623447 -9.924734e+00
# 2102   74152       500.0    2011-03-22        1493  34.715330 -8.881709e+00
# 3711   74153         0.0    2013-02-22        1110  36.659879 -5.131516e+00
# 12942  74154         0.0    2011-03-05        1249  38.326681 -4.458569e+00
# 14830  74162         0.0    2013-03-19        1651  37.962243 -4.494348e+00
# 9435   74173         0.0    2011-07-23        1946  31.367612 -7.788829e+00
# 1113   74179         0.0    2013-02-15           0  33.227131 -4.086316e+00
# 3709   74181         0.0    2013-01-23        1545  34.723827 -4.178447e+00
# 13799  74182         0.0    2011-07-22           0  31.741119 -1.343214e+00
# 10346  74184         0.0    2011-07-18           0  33.242717 -2.524929e+00
# 2220   74198         0.0    2012-10-21           0  32.764025 -5.294412e+00
# 5900   74200         0.0    2013-02-19        1641  37.587551 -3.177921e+00
# 8151   74206      7200.0    2013-03-18        1845  35.906195 -3.182844e+00
# 3154   74209       500.0    2011-03-03        1721  35.142056 -8.241324e+00
# 12796  74212         0.0    2013-02-03           0   0.000000 -2.000000e-08
# 2974   74218       600.0    2012-10-23        1222  34.097966 -1.127777e+00
# 650    74223       150.0    2011-08-11         534  37.627511 -6.745134e+00
# 5960   74231         0.0    2012-11-02           0  32.794546 -5.072416e+00
# 13299  74232         0.0    2012-10-13           0  33.784181 -3.324965e+00
# 11256  74234         0.0    2011-03-27           0  36.075437 -6.223091e+00
# 10876  74241         0.0    2011-03-15           0  36.563607 -6.688495e+00
# 7696   74244         0.0    2013-02-14         695  37.559881 -3.498092e+00
# 6407   74245         0.0    2013-03-04        1420  37.581890 -3.284912e+00
# 11433  74248         0.0    2013-02-16        1280  34.410594 -1.595024e+00
# 5493   74249         0.0    2013-03-11        1473  37.661798 -3.608780e+00
#
#                             wpt_name  num_private                    basin  \
# 3402                         Nairobi            0                  Pangani
# 14136                           none            0  Ruvuma / Southern Coast
# 5702                        Sukumeni            0                  Pangani
# 11739                      Kwa Molen            0              Wami / Ruvu
# 785             Kwa Albert Mwaikombe            0               Lake Nyasa
# 6376              Makumbusho Mwinuka            0               Lake Nyasa
# 405    Shamba La Shule Legeza Mwendo            0               Lake Rukwa
# 114                    Kwa Linda Noa            0                  Pangani
# 5869                      Majalubani            0            Lake Victoria
# 4105                Ihanja Secondary            0                 Internal
# 53                      Kwa Chanzula            0                 Internal
# 6433                   Jafari Chambi            0          Lake Tanganyika
# 3463                        Zahanati            0          Lake Tanganyika
# 8679                          Sowedo            0                  Pangani
# 10067                   Headquarters            0          Lake Tanganyika
# 3121                        Bilalama            0          Lake Tanganyika
# 5965                        Majaliwa            0            Lake Victoria
# 9604                            none            0                   Rufiji
# 14655            Kwa Saruni Olowoiki            0                 Internal
# 4635              Kwa Lugano Kagange            0               Lake Nyasa
# 12301                Kwa Mzee Robert            0                 Internal
# 10174                    Kwa Samweli            0                  Pangani
# 7166                             Aic            0            Lake Victoria
# 3535               Tutu Primary Tank            0                 Internal
# 11581                        Sheunei            0                 Internal
# 10396                         School            0            Lake Victoria
# 3640                  Shuleni Bondwa            0              Wami / Ruvu
# 12658                    Kwa Abraham            0                  Pangani
# 12180              Chemchem Majimoto            0               Lake Rukwa
# 12478          Dp1(Kwa Mwakanyamale)            0               Lake Nyasa
# ...                              ...          ...                      ...
# 6055                  Kwa Mzee Msula            0               Lake Nyasa
# 9671                      Aziza Said            0                  Pangani
# 2274                            none            0               Lake Nyasa
# 7075              Maximillian Robert            0            Lake Victoria
# 6979            Ikelu Primary School            0                   Rufiji
# 14021               Kwa Mzee Maninja            0  Ruvuma / Southern Coast
# 2102             Uhambule Dispensary            0                   Rufiji
# 3711                           Masai            0                 Internal
# 12942                      Kwa Yoswa            0                  Pangani
# 14830                     Kwa Andrew            0                  Pangani
# 9435                     Kwa Sankala            0               Lake Rukwa
# 1113                Mwanshina Centre            0                 Internal
# 3709         Muntamba Primary Tank 2            0                 Internal
# 13799                    Kwa Silakus            0            Lake Victoria
# 10346                     Kwa Chamba            0            Lake Victoria
# 2220            Kwa Ulemela Machongo            0          Lake Tanganyika
# 5900                       Kwa Isaru            0                  Pangani
# 8151                      Kwa Samson            0                 Internal
# 3154                            none            0                   Rufiji
# 12796      Kituo Cha Afya Imalamanuo            0            Lake Victoria
# 2974                Kwa Marco Magote            0            Lake Victoria
# 650                         Kwa Bago            0              Wami / Ruvu
# 5960                      Kwa Msonga            0          Lake Tanganyika
# 13299                    Kwa Nassoro            0                 Internal
# 11256                          Zilpa            0              Wami / Ruvu
# 10876                     Kwamatonya            0              Wami / Ruvu
# 7696                          Sokoni            0                  Pangani
# 6407                Kwa Elimisi Urio            0                  Pangani
# 11433                   Sarayi Mwita            0            Lake Victoria
# 5493               Kwa Mustafa Daudi            0                  Pangani
#
#             region             ...               extraction_type_group  \
# 3402         Tanga             ...                             gravity
# 14136       Ruvuma             ...                      other handpump
# 5702        Arusha             ...                             gravity
# 11739       Dodoma             ...                                mono
# 785          Mbeya             ...                             gravity
# 6376        Iringa             ...                             gravity
# 405          Rukwa             ...                       india mark ii
# 114         Arusha             ...                             gravity
# 5869        Mwanza             ...                         nira/tanira
# 4105       Singida             ...                               other
# 53       Shinyanga             ...                             gravity
# 6433        Tabora             ...                               other
# 3463         Rukwa             ...                             gravity
# 8679   Kilimanjaro             ...                         submersible
# 10067        Rukwa             ...                             gravity
# 3121        Kigoma             ...                             gravity
# 5965        Mwanza             ...                         submersible
# 9604        Iringa             ...                               other
# 14655  Kilimanjaro             ...                             gravity
# 4635         Mbeya             ...                             gravity
# 12301    Shinyanga             ...                         nira/tanira
# 10174  Kilimanjaro             ...                             gravity
# 7166        Mwanza             ...                        wind-powered
# 3535       Singida             ...                             gravity
# 11581       Arusha             ...                             gravity
# 10396       Mwanza             ...                             gravity
# 3640      Morogoro             ...                             gravity
# 12658       Arusha             ...                             gravity
# 12180        Rukwa             ...                             gravity
# 12478        Mbeya             ...                             gravity
# ...            ...             ...                                 ...
# 6055         Mbeya             ...                             gravity
# 9671         Tanga             ...                             gravity
# 2274        Iringa             ...                             gravity
# 7075          Mara             ...                           rope pump
# 6979        Iringa             ...                             gravity
# 14021        Lindi             ...                       india mark ii
# 2102        Iringa             ...                             gravity
# 3711       Manyara             ...                               other
# 12942        Tanga             ...                             gravity
# 14830  Kilimanjaro             ...                             gravity
# 9435         Rukwa             ...                             gravity
# 1113        Tabora             ...                      india mark iii
# 3709       Singida             ...                             gravity
# 13799       Kagera             ...                             gravity
# 10346       Mwanza             ...                               other
# 2220        Tabora             ...                       india mark ii
# 5900   Kilimanjaro             ...                             gravity
# 8151        Arusha             ...                             gravity
# 3154        Iringa             ...                              swn 80
# 12796    Shinyanga             ...                         nira/tanira
# 2974          Mara             ...                         submersible
# 650       Morogoro             ...                             gravity
# 5960        Tabora             ...                         submersible
# 13299    Shinyanga             ...                         nira/tanira
# 11256       Dodoma             ...                                mono
# 10876       Dodoma             ...                             gravity
# 7696   Kilimanjaro             ...                         submersible
# 6407   Kilimanjaro             ...                             gravity
# 11433         Mara             ...                             gravity
# 5493   Kilimanjaro             ...                             gravity
#
#        extraction_type_class        management management_group  \
# 3402                 gravity               vwc       user-group
# 14136               handpump               vwc       user-group
# 5702                 gravity               vwc       user-group
# 11739              motorpump               vwc       user-group
# 785                  gravity               vwc       user-group
# 6376                 gravity               vwc       user-group
# 405                 handpump               vwc       user-group
# 114                  gravity               vwc       user-group
# 5869                handpump               vwc       user-group
# 4105                   other               vwc       user-group
# 53                   gravity               vwc       user-group
# 6433                   other               vwc       user-group
# 3463                 gravity               vwc       user-group
# 8679             submersible   water authority       commercial
# 10067                gravity               vwc       user-group
# 3121                 gravity               vwc       user-group
# 5965             submersible               vwc       user-group
# 9604                   other               vwc       user-group
# 14655                gravity       water board       user-group
# 4635                 gravity               vwc       user-group
# 12301               handpump               wug       user-group
# 10174                gravity               vwc       user-group
# 7166            wind-powered  private operator       commercial
# 3535                 gravity        parastatal       parastatal
# 11581                gravity               vwc       user-group
# 10396                gravity             other            other
# 3640                 gravity               vwc       user-group
# 12658                gravity               vwc       user-group
# 12180                gravity               vwc       user-group
# 12478                gravity               vwc       user-group
# ...                      ...               ...              ...
# 6055                 gravity               vwc       user-group
# 9671                 gravity               vwc       user-group
# 2274                 gravity               vwc       user-group
# 7075               rope pump             other            other
# 6979                 gravity               vwc       user-group
# 14021               handpump               vwc       user-group
# 2102                 gravity               vwc       user-group
# 3711                   other               vwc       user-group
# 12942                gravity               vwc       user-group
# 14830                gravity               vwc       user-group
# 9435                 gravity               vwc       user-group
# 1113                handpump               vwc       user-group
# 3709                 gravity        parastatal       parastatal
# 13799                gravity               vwc       user-group
# 10346                  other               vwc       user-group
# 2220                handpump               vwc       user-group
# 5900                 gravity           company       commercial
# 8151                 gravity               vwc       user-group
# 3154                handpump               vwc       user-group
# 12796               handpump               wug       user-group
# 2974             submersible               vwc       user-group
# 650                  gravity               vwc       user-group
# 5960             submersible               vwc       user-group
# 13299               handpump               wug       user-group
# 11256              motorpump               vwc       user-group
# 10876                gravity               vwc       user-group
# 7696             submersible               wug       user-group
# 6407                 gravity               wua       user-group
# 11433                gravity               wug       user-group
# 5493                 gravity               vwc       user-group
#
#                      payment quality_group      quantity  \
# 3402               never pay          good      seasonal
# 14136              never pay          good      seasonal
# 5702               never pay          good        enough
# 11739         pay per bucket          good           dry
# 785                never pay          good        enough
# 6376   pay when scheme fails          good        enough
# 405                never pay          good        enough
# 114           pay per bucket          good  insufficient
# 5869               never pay          good        enough
# 4105               never pay       unknown  insufficient
# 53            pay per bucket          good  insufficient
# 6433               never pay          good  insufficient
# 3463               never pay          good        enough
# 8679          pay per bucket         salty  insufficient
# 10067            pay monthly          good        enough
# 3121                 unknown          good      seasonal
# 5965               never pay          good  insufficient
# 9604               never pay          good        enough
# 14655            pay monthly          good        enough
# 4635               never pay          good           dry
# 12301              never pay         salty        enough
# 10174              never pay          good        enough
# 7166               never pay          good        enough
# 3535               never pay          good      seasonal
# 11581              never pay          good  insufficient
# 10396              never pay          good  insufficient
# 3640               never pay          good        enough
# 12658              never pay          good        enough
# 12180           pay annually          good        enough
# 12478                unknown          good        enough
# ...                      ...           ...           ...
# 6055               never pay          good  insufficient
# 9671          pay per bucket         salty  insufficient
# 2274            pay annually       unknown       unknown
# 7075               never pay          good        enough
# 6979               never pay          good        enough
# 14021         pay per bucket       colored        enough
# 2102             pay monthly          good  insufficient
# 3711               never pay          good        enough
# 12942              never pay          good        enough
# 14830              never pay          good  insufficient
# 9435               never pay          good        enough
# 1113   pay when scheme fails          good        enough
# 3709               never pay          good      seasonal
# 13799              never pay       unknown           dry
# 10346              never pay          good       unknown
# 2220               never pay          good           dry
# 5900             pay monthly          good        enough
# 8151            pay annually          good        enough
# 3154             pay monthly          good        enough
# 12796              never pay          good        enough
# 2974             pay monthly          good        enough
# 650           pay per bucket          good        enough
# 5960               never pay          good      seasonal
# 13299              never pay          good  insufficient
# 11256                unknown          good           dry
# 10876         pay per bucket          good  insufficient
# 7696               never pay          good  insufficient
# 6407             pay monthly          good        enough
# 11433              never pay          good        enough
# 5493               never pay          good  insufficient
#
#                      source source_class              waterpoint_type
# 3402                 spring  groundwater           communal standpipe
# 14136           machine dbh  groundwater                    hand pump
# 5702                 spring  groundwater                cattle trough
# 11739           machine dbh  groundwater  communal standpipe multiple
# 785                  spring  groundwater           communal standpipe
# 6376                 spring  groundwater           communal standpipe
# 405             machine dbh  groundwater                    hand pump
# 114                  spring  groundwater           communal standpipe
# 5869           shallow well  groundwater                    hand pump
# 4105   rainwater harvesting      surface                        other
# 53                   spring  groundwater  communal standpipe multiple
# 6433           shallow well  groundwater                        other
# 3463                  river      surface           communal standpipe
# 8679            machine dbh  groundwater  communal standpipe multiple
# 10067                spring  groundwater           communal standpipe
# 3121                 spring  groundwater           communal standpipe
# 5965                   lake      surface           communal standpipe
# 9604           shallow well  groundwater                        other
# 14655                spring  groundwater           communal standpipe
# 4635                 spring  groundwater           communal standpipe
# 12301          shallow well  groundwater                    hand pump
# 10174                 river      surface           communal standpipe
# 7166           shallow well  groundwater                        other
# 3535   rainwater harvesting      surface           communal standpipe
# 11581                spring  groundwater  communal standpipe multiple
# 10396                spring  groundwater           communal standpipe
# 3640                  river      surface           communal standpipe
# 12658                spring  groundwater           communal standpipe
# 12180                spring  groundwater              improved spring
# 12478                spring  groundwater           communal standpipe
# ...                     ...          ...                          ...
# 6055                 spring  groundwater           communal standpipe
# 9671            machine dbh  groundwater           communal standpipe
# 2274                 spring  groundwater           communal standpipe
# 7075           shallow well  groundwater                    hand pump
# 6979                 spring  groundwater           communal standpipe
# 14021           machine dbh  groundwater                    hand pump
# 2102                  river      surface           communal standpipe
# 3711            machine dbh  groundwater                        other
# 12942                spring  groundwater           communal standpipe
# 14830                spring  groundwater           communal standpipe
# 9435                  river      surface           communal standpipe
# 1113            machine dbh  groundwater                    hand pump
# 3709   rainwater harvesting      surface           communal standpipe
# 13799                spring  groundwater           communal standpipe
# 10346           machine dbh  groundwater                        other
# 2220           shallow well  groundwater                    hand pump
# 5900                 spring  groundwater           communal standpipe
# 8151                  river      surface           communal standpipe
# 3154               hand dtw  groundwater                    hand pump
# 12796          shallow well  groundwater                    hand pump
# 2974                   lake      surface           communal standpipe
# 650                  spring  groundwater           communal standpipe
# 5960                    dam      surface           communal standpipe
# 13299          shallow well  groundwater                    hand pump
# 11256              hand dtw  groundwater  communal standpipe multiple
# 10876                spring  groundwater           communal standpipe
# 7696                 spring  groundwater           communal standpipe
# 6407                 spring  groundwater           communal standpipe
# 11433                spring  groundwater  communal standpipe multiple
# 5493                  river      surface                        other
#
# [14850 rows x 26 columns]

# %%
df_labels.sort_values(by='id')
# Out:
#           id             status_group
# 9410       0           non functional
# 18428      1               functional
# 12119      2               functional
# 10629      3               functional
# 2343       4           non functional
# 5262       5               functional
# 29892      6           non functional
# 6942       7               functional
# 29473      8           non functional
# 58272      9           non functional
# 35959     11           non functional
# 21963     12           non functional
# 2230      15           non functional
# 30059     16           non functional
# 45308     17               functional
# 39161     18               functional
# 350       19               functional
# 45577     20  functional needs repair
# 7846      21           non functional
# 5395      22               functional
# 32887     23           non functional
# 53936     24           non functional
# 39        25           non functional
# 4697      26               functional
# 22712     27           non functional
# 18019     28               functional
# 50532     30               functional
# 16479     31           non functional
# 27142     33               functional
# 58157     34           non functional
# ...      ...                      ...
# 36485  74208               functional
# 19489  74210  functional needs repair
# 57986  74211               functional
# 6702   74213           non functional
# 11269  74214           non functional
# 24097  74215               functional
# 23724  74216               functional
# 388    74217               functional
# 29818  74219  functional needs repair
# 9984   74220               functional
# 58848  74221           non functional
# 48346  74222           non functional
# 15701  74224               functional
# 49649  74225               functional
# 4595   74226               functional
# 17695  74227               functional
# 49866  74228               functional
# 55834  74229               functional
# 7888   74230               functional
# 22355  74233  functional needs repair
# 49472  74235               functional
# 1319   74236               functional
# 30629  74237           non functional
# 37162  74238           non functional
# 49165  74239           non functional
# 15137  74240               functional
# 8667   74242               functional
# 22584  74243           non functional
# 108    74246           non functional
# 39131  74247           non functional
#
# [59400 rows x 2 columns]

# %%
test_merge.head()
# Out:
# Empty DataFrame
# Columns: [id, status_group, amount_tsh, date_recorded, gps_height, longitude, latitude, wpt_name, num_private, basin, region, region_code, district_code, lga, ward, population, construction_year, extraction_type_group, extraction_type_class, management, management_group, payment, quality_group, quantity, source, source_class, waterpoint_type]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_func1 = predict_map[predict['status_group']=='functional']
df_fix1 = predict_map[predict['status_group']=='functional needs repair']
df_non1 = predict_map[predict['status_group']=='non functional']

# %%
df_func1.to_csv('./func1.csv')

# %%
df_fix1.to_csv('./fix1.csv')

# %%
df_non1.to_csv('./non1.csv')

# %%
df_func1.head()
# Out:
#       id status_group  longitude   latitude
# 0  50785   functional  35.290799  -4.059696
# 1  51630   functional  36.656709  -3.309214
# 2  17168   functional  34.767863  -5.004344
# 3  45559   functional  38.058046  -9.418672
# 4  49871   functional  35.006123 -10.950412

# %%
df_func1.to_csv('./Datasets/Func_predictions.csv')

# %%
df_fix1.head()
# Out:
#         id             status_group  longitude  latitude
# 30   65738  functional needs repair  35.612417 -3.351168
# 75   63059  functional needs repair  33.519206 -3.135247
# 105  17873  functional needs repair  32.305549 -3.508052
# 177  21621  functional needs repair  30.427592 -4.275986
# 199  49259  functional needs repair  36.980594 -3.268179

# %%
df_fix1.to_csv('./Datasets/Fix_predictions.csv')

# %%
df_non1.head()
# Out:
#        id    status_group  longitude   latitude
# 8   36301  non functional  39.262951 -10.823588
# 9   54122  non functional  37.096108  -3.251754
# 20  69961  non functional  39.322307  -6.850262
# 23  30331  non functional  34.621048  -5.165926
# 25  61136  non functional  34.929592  -9.152872

# %%
df_non1.to_csv('./Datasets/Non_predictions.csv')

# %%
predict['status_group'].value_counts()
# Out:
# functional                 9061
# non functional             5231
# functional needs repair     558
# Name: status_group, dtype: int64

# %%
predict['status_group'].value_counts().sum()
# Out:
# 14850

# %%
9061/14850*100
# Out:
# 61.01683501683502

# %%
5231/14850*100
# Out:
# 35.225589225589225

# %%
558/14850*100
# Out:
# 3.7575757575757573

# %%
df_train['status_group'].value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %%
df_train['status_group'].value_counts().sum()
# Out:
# 59400

# %%
32259/59400*100
# Out:
# 54.3080808080808

# %%
22824/59400*100
# Out:
# 38.42424242424242

# %%
4317/59400*100
# Out:
# 7.267676767676767
